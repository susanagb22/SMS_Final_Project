# %% [markdown]
# Condemned & Dead-End Properties Dataset

# %%
import pandas as pd
property = pd.read_csv("Condemned_Properties.csv")
property.head()
# Out:
#       _id         parcel_id                           address  \
# 0  157180  0081A00132000000      No primary address specified
# 1  157181  0174L00014000000      No primary address specified
# 2  157182  0175C00159000000      No primary address specified
# 3  157183  0049N00268000000    321 37TH ST, Pittsburgh, 15201
# 4  157184  0050M00310000000  5452 BROAD ST, Pittsburgh, 15206
#
#                                  owner       property_type        date  \
# 0  MCCOY MARK JOEL & NICOLE HELENA (W)  Condemned Property  2020-05-19
# 1                         BATTLE RAYNA  Condemned Property  2020-05-19
# 2               WHEATON RALEIGH PIERRE  Condemned Property  2020-05-20
# 3                                  NaN  Condemned Property  2020-05-21
# 4                         MONROE BRIAN  Condemned Property  2020-05-28
#
#   latest_inspection_result  latest_inspection_score inspection_status
# 0                     Fail                      9.0          Inactive
# ...
