# %% [markdown]
# #Smart Trash Containers Data Set

# %%
import pandas as pd

trash = pd.read_csv("SmartTrashContainers.csv")
trash.head()
# Out:
#       _id  container_id  receptacle_model_id      assignment_date  \
# 0  384022             1                   74  2017-09-14T13:24:40
# 1  384023             2                   74  2017-09-14T13:24:40
# 2  384024             3                   74  2017-09-14T13:24:40
# 3  384025             4                   74  2017-09-14T13:24:40
# 4  384026             5                   74  2017-09-19T12:22:45
#
#      last_updated_date    group_name           address        city  \
# 0  2022-11-24T13:17:19  1st Division   122 E North Ave  Pittsburgh
# 1  2022-12-31T01:54:25  1st Division  2507 Brighton Rd  Pittsburgh
# 2  2022-04-14T01:59:18  1st Division   1300 Federal St  Pittsburgh
# 3  2022-10-24T12:40:24  1st Division    110 Federal St  Pittsburgh
# 4  2022-12-31T01:58:16  1st Division   490 E North Ave  Pittsburgh
#
#           state    zip        neighborhood  dpw_division  council_district  \
# 0  Pennsylvania  15212   Central Northside           1.0               1.0
# ...
